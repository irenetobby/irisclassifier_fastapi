# %% [markdown]
# <a href="https://colab.research.google.com/github/irenetobby/irisclassifier_fastapi/blob/main/irisclassifier_fastapi_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/iris.csv', sep=';', decimal=',')
df.head()
# defining the X and y
X = df.drop('Classification', axis = 1)
y = df['Classification']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 0)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
model = rfc.fit(X_train,y_train)
#y_pred = model.predict(X_test)
#from sklearn.metrics import accuracy_score
# creating a pickle file
import pickle
pickle_out = open('Classifier.pkl', 'wb')
pickle.dump(model, pickle_out)
pickle_out.close()
